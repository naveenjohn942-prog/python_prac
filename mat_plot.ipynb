# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris=pd.read_csv('Iris.csv')
print(iris.head(10))
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa
# 7   8            5.0           3.4            1.5           0.2  Iris-setosa
# 8   9            4.4           2.9            1.4           0.2  Iris-setosa
# 9  10            4.9           3.1            1.5           0.1  Iris-setosa

# %%
print(iris.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB
# None

# %%
print(iris.shape)
# Out:
# (150, 6)

# %%
print(iris.describe())
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
print(iris.groupby('Species').size())
print(iris.groupby(['Species']).min())
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# dtype: int64
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa        1            4.3           2.3            1.0           0.1
# Iris-versicolor   51            4.9           2.0            3.0           1.0
# Iris-virginica   101            4.9           2.2            4.5           1.4

# %%
iris=iris.drop(columns="Id")#to remove id column

# %%
setosa=iris[iris['Species']=='Iris-setosa']
versicolor=iris[iris['Species']=='Iris-versicolor']
virginica=iris[iris['Species']=='Iris-virginica']

# %%
setosa["SepalWidthCm"].plot(kind="hist",label="setosa",color='b',fontsize=10,density=False)
plt.title('Scatter Plot - Histogram')
plt.xlabel('SepalWidthCm')
plt.show()

# %%
setosa.plot(x="SepalLengthCm", y="SepalWidthCm", kind="scatter",label='setosa',color='r')
plt.title('Scatter Plot - Setosa')
plt.xlabel('SepalLengthCm')
plt.ylabel('PetalLengthCm')
plt.show()

# %%
#line plot
iris["SepalWidthCm"].plot(kind="line",label='setosa',color='black',linewidth='1.5',ls='-')

plt.axis([0,150,2,8])
plt.title('Line Plot')
plt.xlabel('SepalWidthCm')
plt.show()

# %%
#line plot - species wise

setosa["SepalWidthCm"].plot(kind="line",label='setosa',color='black',linewidth='1.5',ls=':')
versicolor["SepalWidthCm"].plot(kind="line",label='setosa',color='black',linewidth='1.5',ls=':')
virginica["SepalWidthCm"].plot(kind="line",label='setosa',color='black',linewidth='1.5',ls=':')
plt.title('species wise-Line Plot')
plt.xlabel('SepalWidthCm')
plt.show()

# %%
#area plot
setosa.plot.area(stacked=False)
plt.show()
setosa.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         5.00600      3.418000       1.464000       0.24400
# std          0.35249      0.381024       0.173511       0.10721
# min          4.30000      2.300000       1.000000       0.10000
# 25%          4.80000      3.125000       1.400000       0.20000
# 50%          5.00000      3.400000       1.500000       0.20000
# 75%          5.20000      3.675000       1.575000       0.30000
# max          5.80000      4.400000       1.900000       0.60000

# %%
versicolor.plot.area(stacked=False)
plt.show()
versicolor.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count      50.000000     50.000000      50.000000     50.000000
# mean        5.936000      2.770000       4.260000      1.326000
# std         0.516171      0.313798       0.469911      0.197753
# min         4.900000      2.000000       3.000000      1.000000
# 25%         5.600000      2.525000       4.000000      1.200000
# 50%         5.900000      2.800000       4.350000      1.300000
# 75%         6.300000      3.000000       4.600000      1.500000
# max         7.000000      3.400000       5.100000      1.800000

# %%
virginica.plot.area(stacked=False)
plt.show()
virginica.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count       50.00000     50.000000      50.000000      50.00000
# mean         6.58800      2.974000       5.552000       2.02600
# std          0.63588      0.322497       0.551895       0.27465
# min          4.90000      2.200000       4.500000       1.40000
# 25%          6.22500      2.800000       5.100000       1.80000
# 50%          6.50000      3.000000       5.550000       2.00000
# 75%          6.90000      3.175000       5.875000       2.30000
# max          7.90000      3.800000       6.900000       2.50000

# %%
#bargraph
Type=list(iris['Species'].unique())
count=list(iris['Species'].value_counts())
Avg=list(iris.groupby('Species')["SepalLengthCm"].mean())
plt.bar(Type, Avg, color=['maroon','yellow','blue'],width=0.4)
plt.title('Bar Plot')
plt.xlabel('SepalLengthCm')
plt.ylabel('AverageSepalLengthCm')

plt.show()

# %%
#pie chart
e=(0.1,0.1,0)
Avg=list(iris.groupby('Species')["SepalLengthCm"].mean())
plt.pie(Avg, explode =e ,labels=['setosa','versicolor','verginica'])
plt.title("Pie Chart")
plt.legend(title="Iris Flowers:")
plt.show()

# %%
#box plot
setosa.plot.box()
plt.title("Box Plot")
plt.legend(labels = ['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm'])

plt.show()

# %%
#not in syllabus
import seaborn as sns
sns.set(style="white")
sns.pairplot(iris, hue="Species")
plt.show()
# Out:
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/codespace/.local/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...
